# %%
#imports
import pandas as pd
import numpy as np
import matplotlib as pyplot
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from scipy import stats

# %%
URL = "https://docs.google.com/spreadsheets/d/1APV3pXiAszS_0mSgkiEt9IUNH-QmyX7KwxSAwuADl6Y/gviz/tq?tqx=out:csv&sheet=medical_data"
df = pd.read_csv(URL)
df.head()
# Out:
#   State       Lat       Lng      Area  Children  Age    Income   Marital  \
# 0    AL  34.34960 -86.72508  Suburban       1.0   53  86575.93  Divorced
# 1    FL  30.84513 -85.22907     Urban       3.0   51  46805.99   Married
# 2    SD  43.54321 -96.63772  Suburban       3.0   53  14370.14   Widowed
# 3    MN  43.89744 -93.51479  Suburban       0.0   78  39741.49   Married
# 4    VA  37.59894 -76.88958     Rural       1.0   22   1209.56   Widowed
#
#    Gender  ReAdmis  ...  Hyperlipidemia  BackPain  Anxiety  Allergic_rhinitis  \
# 0    Male        0  ...             0.0       1.0      1.0                1.0
# 1  Female        0  ...             0.0       0.0      0.0                0.0
# 2  Female        0  ...             0.0       0.0      0.0                0.0
# 3    Male        0  ...             0.0       0.0      0.0                0.0
# 4  Female        0  ...             1.0       0.0      0.0                1.0
#
# ...

# %% [markdown]
# VitD_levels

# %%
# Histogram for VitD_levels
col = "VitD_levels"
feature = df[col]
#Getting measures of central tendency
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
# Plotting graph
ax = sns.histplot(feature,stat='probability',kde=True)
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'Histogram for {col}')
ax.legend();

kurt = stats.kurtosis(df[col], fisher = False)
print(f"Kurtosis score for VitD_levels is {kurt}")
# Out:
# Kurtosis score for VitD_levels is 3.013147515833447

# %% [markdown]
# Is it Discrete or Continuous?
#
# -Continuous

# %% [markdown]
# Does it have a skew? If so, which direction (+/-)
#
# -Normal

# %% [markdown]
# What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
#
# -Mesokurtic

# %% [markdown]
# Doc_visits

# %%
# Histogram for Doc_visits
col = "Doc_visits"
feature = df[col]
#Getting measures of central tendency
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
# Plotting graph
ax = sns.histplot(feature,stat='probability',kde=True)
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'Histogram for {col}')
ax.legend();

kurt = stats.kurtosis(df[col], fisher = False)
print(f"Kurtosis score for Doc_visits is {kurt}")
# Out:
# Kurtosis score for Doc_visits is 2.9919958083381206

# %% [markdown]
# Is it Discrete or Continuous?
#
# -Discrete

# %% [markdown]
# Does it have a skew? If so, which direction (+/-)
#
# -Normal

# %% [markdown]
# What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
#
# -Platykurtic

# %% [markdown]
# TotalCharge

# %%
# Histogram for TotalCharge
col = "TotalCharge"
feature = df[col]
#Getting measures of central tendency
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
# Plotting graph
ax = sns.histplot(feature,stat='probability',kde=True)
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'Histogram for {col}')
ax.legend();

kurt = stats.kurtosis(df[col], fisher = False)
print(f"Kurtosis score for TotalCharge is {kurt}")
# Out:
# Kurtosis score for TotalCharge is 3.2650077463439384

# %% [markdown]
# Is it Discrete or Continuous?
#
# -Continuous

# %% [markdown]
# Does it have a skew? If so, which direction (+/-)
#
# -Positively skewed

# %% [markdown]
# What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
#
# -Leptokurtic
